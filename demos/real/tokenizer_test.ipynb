# %%
from pathlib import Path
import sys

repo_root = Path.cwd()

while not (repo_root / "src").exists():
    if repo_root.parent == repo_root:
        raise RuntimeError("Could not find 'src' directory in any parent")
    repo_root = repo_root.parent

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
import matplotlib.pyplot as plt
from demos.real.base_batched_gpu_benchmark_task_variants import BaseBatchedGPUBenchmarkTask

# %%
instance = BaseBatchedGPUBenchmarkTask(None)
tokenizer = instance.tokenizer
# Out:
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]

# %%
import random
import string

def generate_random_strings(n, a, b, seed=42):
    random.seed(seed)  # set seed for reproducibility
    chars = string.ascii_letters + string.digits  # a-z, A-Z, 0-9
    result = []
    for _ in range(n):
        length = random.randint(a, b)
        rand_str = ''.join(random.choice(chars) for _ in range(length))
        result.append(rand_str)
    return result

# %%
print(max(map(len, map(tokenizer.encode, generate_random_strings(1000, 1, 1300)))))
plt.hist(list(map(len, map(tokenizer.encode, generate_random_strings(1000, 1, 1300)))))
plt.show()
# Out:
# 1000

# %%
print(max(map(len, map(tokenizer.encode, generate_random_strings(1000, 1, 500)))))
plt.hist(list(map(len, map(tokenizer.encode, generate_random_strings(1000, 1, 500)))))
plt.show()
# Out:
# 391

# %%
instance(["ewifwf", "frhwoicj"])
# Out:
# BaseModelOutputWithPoolingAndCrossAttentions(last_hidden_state=tensor([[[-1.0245e+00, -2.7781e-03,  1.5413e-01,  ...,  7.7749e-01,
#           -6.9024e-01,  2.3731e+00],
#          [-6.0520e-01, -3.0731e-02,  3.1336e-01,  ...,  6.1767e-01,
#           -5.2598e-01,  1.4765e+00],
#          [-8.6329e-01, -1.9167e-01,  1.5600e-03,  ...,  6.1112e-01,
#           -7.9922e-01,  1.6252e+00],
#          ...,
#          [-1.0374e+00, -4.7910e-01, -9.7314e-02,  ...,  7.9586e-01,
#           -1.2529e+00,  1.3299e+00],
#          [-7.1934e-01,  3.5506e-01,  5.6203e-02,  ...,  1.3168e-01,
#           -1.5794e+00,  1.1793e+00],
#          [-6.7439e-01,  7.9756e-02,  3.6750e-01,  ...,  6.4051e-01,
#           -1.0168e+00,  1.6591e+00]],
#
#         [[-5.2868e-01,  1.1445e+00, -4.0781e-01,  ...,  1.2856e-02,
#            1.8710e-01,  1.4677e+00],
#          [ 8.8417e-02,  6.4844e-01, -2.8786e-01,  ...,  1.9912e-01,
#           -6.4540e-01,  1.2568e+00],
# ...
